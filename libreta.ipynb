# %%
print("Hola mi libreta!")
# Out:
# Hola mi libreta!

# %%
import torch
print("torch version:", torch.__version__)
print("CUDA visible:", torch.cuda.is_available())
print("torch.cuda.version:", torch.version.cuda)
print("num GPUs:", torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    print(torch.cuda.get_device_properties(0))
# Out:
# torch version: 2.5.1
# CUDA visible: True
# torch.cuda.version: 12.1
# num GPUs: 1
# NVIDIA GeForce RTX 3050 Laptop GPU
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 3050 Laptop GPU', major=8, minor=6, total_memory=4095MB, multi_processor_count=16, uuid=5fa823c0-4c6d-1585-758e-558f60fc8cdb, L2_cache_size=1MB)

# %%
x = torch.randn(1024,1024, device='cuda')
y = (x * 2.0).sum()
print(y.item())
# Out:
# 393.99542236328125

# %%
# !nvidia-smi
# Out:
# Sat Dec 27 18:27:23 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.29                 Driver Version: 581.29         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   50C    P0             10W /   70W |     991MiB /   4096MiB |      2%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1416    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            3136    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            3468    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            7356    C+G   ....0.3650.96\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            9836    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           11492    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           11564      C   ...conda3\envs\ai-gpu\python.exe      N/A      |
# |    0   N/A  N/A           12968    C+G   ....0.3650.96\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           13072    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           13080    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16604    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           17064    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           18096    C+G   ...onsoftware\RadeonSoftware.exe      N/A      |
# |    0   N/A  N/A           20516    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           21896    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A           22552    C+G   ...Files\Notepad++\notepad++.exe      N/A      |
# |    0   N/A  N/A           24376    C+G   ...adeonsoftware\AMDRSSrcExt.exe      N/A      |
# +-----------------------------------------------------------------------------------------+
